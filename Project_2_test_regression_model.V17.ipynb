# %%
# Import the necessary packages.
import os
import pandas as pd
import numpy as np
import xgboost as xgb
import shap as shap
# %pip install shapiq
shap.initjs()
# %pip install lightgbm
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import xgboost as xgb
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer
# Out:
# Requirement already satisfied: shapiq in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.13.1)
# Requirement already satisfied: pandas in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.4.2)
# Requirement already satisfied: tqdm in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (4.66.4)
# Requirement already satisfied: requests in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.32.2)
# Requirement already satisfied: matplotlib in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.8.4)
# Requirement already satisfied: colour in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (0.1.5)
# Requirement already satisfied: networkx in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (2.2.0)
# Requirement already satisfied: colorama in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from tqdm->shapiq) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib->shapiq) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Requirement already satisfied: lightgbm in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from lightgbm) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Check the current working directory.
print("Current Working Directory:", os.getcwd())

# List all files in the current working directory.
print("Files in the current directory:", os.listdir())
# Out:
# Current Working Directory: c:\Users\kerim\OneDrive\Desktop\Project-2\Archive
# Files in the current directory: ['adj_r2_model1.joblib', 'adj_r2_model2.joblib', 'Carson_cleaned.ipynb', 'Carson_cleaned_1.ipynb', 'Cleaned.csv', 'cross_val_mean.joblib', 'cross_val_mean2.joblib', 'GroupProject2.ipynb', 'Metro_invt_fs_uc_sfrcondo_sm_month.csv', 'Metro_market_temp_index_uc_sfrcondo_month (1).csv', 'Metro_market_temp_index_uc_sfrcondo_month.csv', 'Metro_mean_doz_pending_uc_sfrcondo_sm_month.csv', 'Metro_new_con_sales_count_raw_uc_sfrcondo_month.csv', 'Metro_sales_count_now_uc_sfrcondo_month.csv', 'Metro_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv', 'Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month (1) (1).csv', 'Metro_zori_uc_sfrcondomfr_sm_month (1).csv', 'model1.joblib', 'model2.joblib', 'models.ipynb', 'models_1.ipynb', 'Project_2_test_regression_model.ipynb', 'Project_2_test_regression_model.V10.ipynb', 'Project_2_test_regression_model.V11.ipynb', 'Project_2_test_regression_model.V12.ipynb', 'Project_2_test_regression_model.V13.ipynb', 'Project_2_test_regression_model.V14.ipynb', 'Project_2_test_regression_model.V15.ipynb', 'Project_2_test_regression_model.V16.ipynb', 'Project_2_test_regression_model.V17.ipynb', 'Project_2_test_regression_model.V2.ipynb', 'Project_2_test_regression_model.V3.ipynb', 'Project_2_test_regression_model.V4.ipynb', 'Project_2_test_regression_model.V5.ipynb', 'Project_2_test_regression_model.V6.ipynb', 'Project_2_test_regression_model.V7.ipynb', 'Project_2_test_regression_model.V8.ipynb', 'Project_2_test_regression_model.V9.ipynb', 'README(2).md', 'Rentcast Ian Data.ipynb', 'rentcast_propertylisting.ipynb', 'results_model1.csv', 'results_model2.csv', 'utah_sales_20241203_201859.csv', 'utah_sales_20241203_201859.KA.zip', 'X_test.joblib', 'X_train.joblib', 'y_test.joblib', 'y_train.joblib']

# %%
# Initialize the dataframe.
df = pd.DataFrame()

# Read in the data file.
file_path = 'utah_sales_20241203_201859.csv'
if file_path in os.listdir():
	file = pd.read_csv(file_path)
	df = pd.DataFrame(file)
	df.dropna(inplace=True)
	df.head()
else:
	print(f"File '{file_path}' not found in the current directory.")

# Display the first few rows of the dataframe.
print(df.head())
# Out:
# C:\Users\kerim\AppData\Local\Temp\ipykernel_22908\3697229256.py:7: DtypeWarning: Columns (11,12,13,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv(file_path)
#                                                    id  \
# 8     13647-S-Vernet-Dr-W,---2039,-Riverton,-UT-84096
# 11  1046-E-Blazing-Sun-Dr,---324,-Eagle-Mountain,-...
# 13     3612-N-Huntsman-Path,-Unit-609,-Eden,-UT-84310
# 17  4608-W-Hemsworth-Ln-S,---2067,-Riverton,-UT-84096
# 24  3155-S-Hidden-Valley-Dr,-Unit-208,-Saint-Georg...
#
#                                      formattedAddress  \
# 8     13647 S Vernet Dr W, # 2039, Riverton, UT 84096
# 11  1046 E Blazing Sun Dr, # 324, Eagle Mountain, ...
# 13     3612 N Huntsman Path, Unit 609, Eden, UT 84310
# 17  4608 W Hemsworth Ln S, # 2067, Riverton, UT 84096
# 24  3155 S Hidden Valley Dr, Unit 208, Saint Georg...
#
#                addressLine1 addressLine2            city state  zipCode  \
# 8       13647 S Vernet Dr W       # 2039        Riverton    UT    84096
# 11    1046 E Blazing Sun Dr        # 324  Eagle Mountain    UT    84005
# 13     3612 N Huntsman Path     Unit 609            Eden    UT    84310
# 17    4608 W Hemsworth Ln S       # 2067        Riverton    UT    84096
# 24  3155 S Hidden Valley Dr     Unit 208    Saint George    UT    84790
#
#         county   latitude   longitude  ... squareFootage lotSize yearBuilt  \
# 8    Salt Lake  40.503300 -112.001572  ...        3622.0  1307.0    2024.0
# 11        Utah  40.322655 -112.023788  ...        4054.0  9148.0    2024.0
# 13       Weber  41.324364 -111.823717  ...        1100.0  3485.0    2002.0
# 17   Salt Lake  40.504021 -112.000793  ...        2280.0  1307.0    2024.0
# 24  Washington  37.053494 -113.569428  ...        1430.0   871.0    2006.0
#
#       status   price                listedDate               removedDate  \
# 8   Inactive  588900  2024-01-16T00:00:00.000Z  2024-04-06T00:00:00.000Z
# 11  Inactive  632525  2024-01-18T00:00:00.000Z  2024-04-06T00:00:00.000Z
# 13  Inactive  505000  2024-01-24T00:00:00.000Z  2024-04-06T00:00:00.000Z
# 17  Inactive  501900  2024-01-29T00:00:00.000Z  2024-04-06T00:00:00.000Z
# 24  Inactive  309900  2024-02-10T00:00:00.000Z  2024-04-06T00:00:00.000Z
#
#                  createdDate              lastSeenDate daysOnMarket
# 8   2024-02-14T00:00:00.000Z  2024-04-05T00:00:00.000Z         81.0
# 11  2024-01-19T00:00:00.000Z  2024-04-05T00:00:00.000Z         79.0
# 13  2021-08-19T11:30:57.821Z  2024-04-05T00:00:00.000Z         73.0
# 17  2024-02-29T00:00:00.000Z  2024-04-05T00:00:00.000Z         68.0
# 24  2024-02-10T00:00:00.000Z  2024-04-05T00:00:00.000Z         56.0
#
# [5 rows x 23 columns]

# %%
# Display the columns of the dataframe.
df.keys()
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
#        'bedrooms', 'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt',
#        'status', 'price', 'listedDate', 'removedDate', 'createdDate',
#        'lastSeenDate', 'daysOnMarket'],
#       dtype='object')

# %%
# Check the data types of the columns.
df.info()

# Check the current working directory
print("Current Working Directory:", os.getcwd())

# List all files in the current working directory
print("Files in the current directory:", os.listdir())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15115 entries, 8 to 82535
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                15115 non-null  object
#  1   formattedAddress  15115 non-null  object
#  2   addressLine1      15115 non-null  object
#  3   addressLine2      15115 non-null  object
#  4   city              15115 non-null  object
#  5   state             15115 non-null  object
#  6   zipCode           15115 non-null  int64
#  7   county            15115 non-null  object
#  8   latitude          15115 non-null  float64
#  9   longitude         15115 non-null  float64
#  10  propertyType      15115 non-null  object
#  11  bedrooms          15115 non-null  object
#  12  bathrooms         15115 non-null  object
#  13  squareFootage     15115 non-null  object
#  14  lotSize           15115 non-null  object
#  15  yearBuilt         15115 non-null  object
#  16  status            15115 non-null  object
#  17  price             15115 non-null  object
#  18  listedDate        15115 non-null  object
#  19  removedDate       15115 non-null  object
#  20  createdDate       15115 non-null  object
#  21  lastSeenDate      15115 non-null  object
#  22  daysOnMarket      15115 non-null  float64
# dtypes: float64(3), int64(1), object(19)
# memory usage: 2.8+ MB
# Current Working Directory: c:\Users\kerim\OneDrive\Desktop\Project-2\Archive
# Files in the current directory: ['adj_r2_model1.joblib', 'adj_r2_model2.joblib', 'Carson_cleaned.ipynb', 'Carson_cleaned_1.ipynb', 'Cleaned.csv', 'cross_val_mean.joblib', 'cross_val_mean2.joblib', 'GroupProject2.ipynb', 'Metro_invt_fs_uc_sfrcondo_sm_month.csv', 'Metro_market_temp_index_uc_sfrcondo_month (1).csv', 'Metro_market_temp_index_uc_sfrcondo_month.csv', 'Metro_mean_doz_pending_uc_sfrcondo_sm_month.csv', 'Metro_new_con_sales_count_raw_uc_sfrcondo_month.csv', 'Metro_sales_count_now_uc_sfrcondo_month.csv', 'Metro_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv', 'Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month (1) (1).csv', 'Metro_zori_uc_sfrcondomfr_sm_month (1).csv', 'model1.joblib', 'model2.joblib', 'models.ipynb', 'models_1.ipynb', 'Project_2_test_regression_model.ipynb', 'Project_2_test_regression_model.V10.ipynb', 'Project_2_test_regression_model.V11.ipynb', 'Project_2_test_regression_model.V12.ipynb', 'Project_2_test_regression_model.V13.ipynb', 'Project_2_test_regression_model.V14.ipynb', 'Project_2_test_regression_model.V15.ipynb', 'Project_2_test_regression_model.V16.ipynb', 'Project_2_test_regression_model.V17.ipynb', 'Project_2_test_regression_model.V2.ipynb', 'Project_2_test_regression_model.V3.ipynb', 'Project_2_test_regression_model.V4.ipynb', 'Project_2_test_regression_model.V5.ipynb', 'Project_2_test_regression_model.V6.ipynb', 'Project_2_test_regression_model.V7.ipynb', 'Project_2_test_regression_model.V8.ipynb', 'Project_2_test_regression_model.V9.ipynb', 'README(2).md', 'Rentcast Ian Data.ipynb', 'rentcast_propertylisting.ipynb', 'results_model1.csv', 'results_model2.csv', 'utah_sales_20241203_201859.csv', 'utah_sales_20241203_201859.KA.zip', 'X_test.joblib', 'X_train.joblib', 'y_test.joblib', 'y_train.joblib']

# %%
# Display the unique property types in the dataframe.
df['propertyType'].unique()
# Out:
# array(['Townhouse', 'Single Family', 'Condo', 'Manufactured',
#        'Multi-Family', 'Land'], dtype=object)

# %%
# Display the dataframe columns.
columns_to_drop = ['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
       'state', 'listedDate', 'removedDate', 'createdDate', 'lastSeenDate', 'status', 'county']
columns_to_drop = [col for col in columns_to_drop if col in df.columns]
dropped = df.drop(columns=columns_to_drop)

# %%
# Estalish the property type conditions.
my_conditions = ['Apartment','Manufactured',
       'Multi-Family','Land', 'nan', '2.0', '3.0', '5.0', '7.0',
       '6.0', '4.0', '0.0', '10.0', '1.0', '8.0', '12.0', 'Inactive']

# %%
# Clean the dataframe by establishing additional conditions.
dropped_cleaned = dropped[~dropped['propertyType'].isin(my_conditions)]
dropped_cleaned = dropped_cleaned[dropped_cleaned["lotSize"] != "Inactive"]
dropped_cleaned = dropped_cleaned[dropped_cleaned["squareFootage"] != "Inactive"]
dropped_cleaned = dropped_cleaned[dropped_cleaned["bedrooms"] != "Inactive"]
dropped_cleaned = dropped_cleaned[dropped_cleaned["bathrooms"] != "Inactive"]
dropped_cleaned = dropped_cleaned[dropped_cleaned["price"] != "Inactive"]
dropped_cleaned = dropped_cleaned[dropped_cleaned["yearBuilt"] != "Inactive"]
dropped_cleaned = dropped_cleaned[dropped_cleaned["lotSize"] != "Inactive"]

# Check if 'latitude' and 'longitude' columns exist before filtering
if 'latitude' in dropped_cleaned.columns:
	dropped_cleaned = dropped_cleaned[dropped_cleaned["latitude"] != "Inactive"]
if 'longitude' in dropped_cleaned.columns:
	dropped_cleaned = dropped_cleaned[dropped_cleaned["longitude"] != "Inactive"]

dropped_cleaned = dropped_cleaned[dropped_cleaned["propertyType"] != "Inactive"]

# Ensure 'lotSize' column is of string type before using .str accessor
dropped_cleaned["lotSize"] = dropped_cleaned["lotSize"].astype(str)
dropped_cleaned = dropped_cleaned[dropped_cleaned["lotSize"].str.len().between(0, 8)]

dropped_cleaned = dropped_cleaned.dropna()
dropped_cleaned
# Out:
#        zipCode   latitude   longitude   propertyType bedrooms bathrooms  \
# 8        84096  40.503300 -112.001572      Townhouse      5.0       3.0
# 11       84005  40.322655 -112.023788  Single Family      3.0       2.5
# 13       84310  41.324364 -111.823717          Condo      2.0       2.0
# 17       84096  40.504021 -112.000793      Townhouse      3.0       2.5
# 24       84790  37.053494 -113.569428      Townhouse      3.0       2.5
# ...        ...        ...         ...            ...      ...       ...
# 82505    84790  37.049554 -113.554598      Townhouse      3.0       3.0
# 82508    84341  41.790873 -111.787867  Single Family      8.0       5.0
# 82515    84762  37.490615 -112.778916  Single Family      1.0       2.0
# 82522    84340  41.394288 -112.035649  Single Family      4.0       3.0
# 82535    84720  37.679365 -113.063825          Condo      2.0       2.0
#
#       squareFootage   lotSize yearBuilt    price  daysOnMarket
# 8            3622.0    1307.0    2024.0   588900          81.0
# 11           4054.0    9148.0    2024.0   632525          79.0
# 13           1100.0    3485.0    2002.0   505000          73.0
# 17           2280.0    1307.0    2024.0   501900          68.0
# 24           1430.0     871.0    2006.0   309900          56.0
# ...             ...       ...       ...      ...           ...
# 82505        1465.0     871.0    2015.0   335000         515.0
# 82508        7036.0   26136.0    2005.0  1165000         126.0
# 82515         300.0  115870.0    2014.0   110000         255.0
# 82522        3326.0   11761.0    2022.0   648000          45.0
# 82535        1037.0    2178.0    1985.0   255000           8.0
#
# [12434 rows x 11 columns]

# %%
# Display the unique property types in the cleaned dataframe.
dropped_cleaned.keys()
# Out:
# Index(['zipCode', 'latitude', 'longitude', 'propertyType', 'bedrooms',
#        'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt', 'price',
#        'daysOnMarket'],
#       dtype='object')

# %%
# Convert fields to the proper data type and remove outliers meeting the following conditions:
# Bedrooms greater than 10
# Bathrooms greater than 8.5
# Square footage greater than 20K
# Year built greater than 2024
# Year built less than 1920
# Bedrooms less than 1
# Price under 15K
# Zip code greater than or equal to 99999

dropped_cleaned[['zipCode','bedrooms', 'bathrooms', 'squareFootage',
       'lotSize', 'yearBuilt', 'price', 'daysOnMarket']] = dropped_cleaned[['zipCode','bedrooms', 'bathrooms', 'squareFootage',
       'lotSize', 'yearBuilt', 'price', 'daysOnMarket']].apply(pd.to_numeric, errors="coerce")
dropped_cleaned = dropped_cleaned[dropped_cleaned['zipCode'] < 99998]
dropped_cleaned = dropped_cleaned[dropped_cleaned['bathrooms'] < 8.5]
dropped_cleaned = dropped_cleaned[dropped_cleaned['bedrooms'] < 10]
dropped_cleaned = dropped_cleaned[dropped_cleaned['squareFootage'] < 20000]
dropped_cleaned = dropped_cleaned[dropped_cleaned['yearBuilt'] > 1920]
dropped_cleaned = dropped_cleaned[dropped_cleaned['yearBuilt'] < 2025]
dropped_cleaned = dropped_cleaned[dropped_cleaned['bedrooms'] > 0]

# %%
# Display the cleaned dataframe.
le = LabelEncoder()
dropped_cleaned['propertyType'] = le.fit_transform(dropped_cleaned['propertyType'])
dropped_cleaned
# Out:
#        zipCode   latitude   longitude  propertyType  bedrooms  bathrooms  \
# 8        84096  40.503300 -112.001572             2       5.0        3.0
# 11       84005  40.322655 -112.023788             1       3.0        2.5
# 13       84310  41.324364 -111.823717             0       2.0        2.0
# 17       84096  40.504021 -112.000793             2       3.0        2.5
# 24       84790  37.053494 -113.569428             2       3.0        2.5
# ...        ...        ...         ...           ...       ...        ...
# 82505    84790  37.049554 -113.554598             2       3.0        3.0
# 82508    84341  41.790873 -111.787867             1       8.0        5.0
# 82515    84762  37.490615 -112.778916             1       1.0        2.0
# 82522    84340  41.394288 -112.035649             1       4.0        3.0
# 82535    84720  37.679365 -113.063825             0       2.0        2.0
#
#        squareFootage   lotSize  yearBuilt    price  daysOnMarket
# 8             3622.0    1307.0     2024.0   588900          81.0
# 11            4054.0    9148.0     2024.0   632525          79.0
# 13            1100.0    3485.0     2002.0   505000          73.0
# 17            2280.0    1307.0     2024.0   501900          68.0
# 24            1430.0     871.0     2006.0   309900          56.0
# ...              ...       ...        ...      ...           ...
# 82505         1465.0     871.0     2015.0   335000         515.0
# 82508         7036.0   26136.0     2005.0  1165000         126.0
# 82515          300.0  115870.0     2014.0   110000         255.0
# 82522         3326.0   11761.0     2022.0   648000          45.0
# 82535         1037.0    2178.0     1985.0   255000           8.0
#
# [12347 rows x 11 columns]

# %%
# Display the details of the cleaned dataframe.
dropped_cleaned.dtypes
# Out:
# zipCode            int64
# latitude         float64
# longitude        float64
# propertyType       int32
# bedrooms         float64
# bathrooms        float64
# squareFootage    float64
# lotSize          float64
# yearBuilt        float64
# price              int64
# daysOnMarket     float64
# dtype: object

# %%
# Display the scores for dropped_clean.
for x in dropped_cleaned:
    score = dropped_cleaned[x].max()
    print(score)
# Out:
# 84790
# 41.979897
# -109.136174
# 2
# 9.0
# 8.0
# 12297.0
# 977922.0
# 2024.0
# 22900000
# 1092.0

# %%
# Display the cleaned dataframe.
df = dropped_cleaned
for col in df.columns:
    try:
        pd.to_numeric(df[col])
    except ValueError:
        print(f"Non-numeric data found in column: {col}")
df
# Out:
#        zipCode   latitude   longitude  propertyType  bedrooms  bathrooms  \
# 8        84096  40.503300 -112.001572             2       5.0        3.0
# 11       84005  40.322655 -112.023788             1       3.0        2.5
# 13       84310  41.324364 -111.823717             0       2.0        2.0
# 17       84096  40.504021 -112.000793             2       3.0        2.5
# 24       84790  37.053494 -113.569428             2       3.0        2.5
# ...        ...        ...         ...           ...       ...        ...
# 82505    84790  37.049554 -113.554598             2       3.0        3.0
# 82508    84341  41.790873 -111.787867             1       8.0        5.0
# 82515    84762  37.490615 -112.778916             1       1.0        2.0
# 82522    84340  41.394288 -112.035649             1       4.0        3.0
# 82535    84720  37.679365 -113.063825             0       2.0        2.0
#
#        squareFootage   lotSize  yearBuilt    price  daysOnMarket
# 8             3622.0    1307.0     2024.0   588900          81.0
# 11            4054.0    9148.0     2024.0   632525          79.0
# 13            1100.0    3485.0     2002.0   505000          73.0
# 17            2280.0    1307.0     2024.0   501900          68.0
# 24            1430.0     871.0     2006.0   309900          56.0
# ...              ...       ...        ...      ...           ...
# 82505         1465.0     871.0     2015.0   335000         515.0
# 82508         7036.0   26136.0     2005.0  1165000         126.0
# 82515          300.0  115870.0     2014.0   110000         255.0
# 82522         3326.0   11761.0     2022.0   648000          45.0
# 82535         1037.0    2178.0     1985.0   255000           8.0
#
# [12347 rows x 11 columns]

# %%
# Convert all of the string data to numbers with one hot encoder or get dummies.
# df = pd.get_dummies(df, columns=['city', 'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
# 'bedrooms', 'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt','status', 'listedDate', 'removedDate', 'createdDate', 'daysOnMarket'])

# %%
# Display the dataframe column headers.
df.head()
# Out:
#     zipCode   latitude   longitude  propertyType  bedrooms  bathrooms  \
# 8     84096  40.503300 -112.001572             2       5.0        3.0
# 11    84005  40.322655 -112.023788             1       3.0        2.5
# 13    84310  41.324364 -111.823717             0       2.0        2.0
# 17    84096  40.504021 -112.000793             2       3.0        2.5
# 24    84790  37.053494 -113.569428             2       3.0        2.5
#
#     squareFootage  lotSize  yearBuilt   price  daysOnMarket
# 8          3622.0   1307.0     2024.0  588900          81.0
# 11         4054.0   9148.0     2024.0  632525          79.0
# 13         1100.0   3485.0     2002.0  505000          73.0
# 17         2280.0   1307.0     2024.0  501900          68.0
# 24         1430.0    871.0     2006.0  309900          56.0

# %%
# Split the data into training and testing sets
X = df.drop('price', axis=1)
y = df['price'] / 1e6
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
# Print x_train column headers.
X_train.head()
# Out:
#        zipCode   latitude   longitude  propertyType  bedrooms  bathrooms  \
# 2325     84720  37.680984 -113.145535             1       5.0        2.5
# 32736    84790  37.011917 -113.598160             2       3.0        2.5
# 81832    84414  41.311148 -111.962272             1       3.0        1.0
# 26017    84770  37.126242 -113.610708             1       3.0        2.0
# 428      84790  37.049639 -113.554287             2       3.0        2.5
#
#        squareFootage  lotSize  yearBuilt  daysOnMarket
# 2325          2300.0  13068.0     2023.0          92.0
# 32736         1611.0   1742.0     2023.0         397.0
# 81832         2018.0   9148.0     1960.0          29.0
# 26017         1624.0   1742.0     1988.0         374.0
# 428           1475.0    871.0     2015.0          14.0

# %%
# Print the first 5 rows of the y_train data.
y_train.head()
# Out:
# 2325     0.46900
# 32736    0.44689
# 81832    0.41950
# 26017    0.37990
# 428      0.31000
# Name: price, dtype: float64

# %%
# Make an X variable with all columns except price
X_full = df.drop(columns = ['price'])
X_full.columns
# Out:
# Index(['zipCode', 'latitude', 'longitude', 'propertyType', 'bedrooms',
#        'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt', 'daysOnMarket'],
#       dtype='object')

# %%
X_full.head()
# Out:
#     zipCode   latitude   longitude  propertyType  bedrooms  bathrooms  \
# 8     84096  40.503300 -112.001572             2       5.0        3.0
# 11    84005  40.322655 -112.023788             1       3.0        2.5
# 13    84310  41.324364 -111.823717             0       2.0        2.0
# 17    84096  40.504021 -112.000793             2       3.0        2.5
# 24    84790  37.053494 -113.569428             2       3.0        2.5
#
#     squareFootage  lotSize  yearBuilt  daysOnMarket
# 8          3622.0   1307.0     2024.0          81.0
# 11         4054.0   9148.0     2024.0          79.0
# 13         1100.0   3485.0     2002.0          73.0
# 17         2280.0   1307.0     2024.0          68.0
# 24         1430.0    871.0     2006.0          56.0

# %%
# Make a y variable with the price column
y = df['price']/ 1e6

# %%
# # Use get_dummies to make categorical variables into numerical.
# X = pd.get_dummies(X_full)

# %%
# Select the dataframe features.
select_features = ['latitude', 'longitude', 'squareFootage', 'lotSize', 'bathrooms', 'bedrooms', 'yearBuilt', 'daysOnMarket', 'propertyType']

# %%
# Display the columns for the select_features.
select_features
# Out:
# ['latitude',
#  'longitude',
#  'squareFootage',
#  'lotSize',
#  'bathrooms',
#  'bedrooms',
#  'yearBuilt',
#  'daysOnMarket',
#  'propertyType']

# %%
# Create another variable X_sel with only the columns in the "select_features" list.
# Ensure the columns in select_features exist in the dataframe
select_features = [col for col in select_features if col in df.columns]
X_sel = df[select_features]
X_sel
# Out:
#         latitude   longitude  squareFootage   lotSize  bathrooms  bedrooms  \
# 8      40.503300 -112.001572         3622.0    1307.0        3.0       5.0
# 11     40.322655 -112.023788         4054.0    9148.0        2.5       3.0
# 13     41.324364 -111.823717         1100.0    3485.0        2.0       2.0
# 17     40.504021 -112.000793         2280.0    1307.0        2.5       3.0
# 24     37.053494 -113.569428         1430.0     871.0        2.5       3.0
# ...          ...         ...            ...       ...        ...       ...
# 82505  37.049554 -113.554598         1465.0     871.0        3.0       3.0
# 82508  41.790873 -111.787867         7036.0   26136.0        5.0       8.0
# 82515  37.490615 -112.778916          300.0  115870.0        2.0       1.0
# 82522  41.394288 -112.035649         3326.0   11761.0        3.0       4.0
# 82535  37.679365 -113.063825         1037.0    2178.0        2.0       2.0
#
#        yearBuilt  daysOnMarket  propertyType
# 8         2024.0          81.0             2
# 11        2024.0          79.0             1
# 13        2002.0          73.0             0
# 17        2024.0          68.0             2
# 24        2006.0          56.0             2
# ...          ...           ...           ...
# 82505     2015.0         515.0             2
# 82508     2005.0         126.0             1
# 82515     2014.0         255.0             1
# 82522     2022.0          45.0             1
# 82535     1985.0           8.0             0
#
# [12347 rows x 9 columns]

# %%
# Set the target variable y.
y = df['price'] / 1e6
y
# Out:
# 8        0.588900
# 11       0.632525
# 13       0.505000
# 17       0.501900
# 24       0.309900
#            ...
# 82505    0.335000
# 82508    1.165000
# 82515    0.110000
# 82522    0.648000
# 82535    0.255000
# Name: price, Length: 12347, dtype: float64

# %%
# Now split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (10494, 10) (1853, 10) (10494,) (1853,)

# %% [markdown]
# ## Train the models

# %%
# Print the x-train model
print(X_train)
# Out:
#        zipCode   latitude   longitude  propertyType  bedrooms  bathrooms  \
# 2325     84720  37.680984 -113.145535             1       5.0        2.5
# 32736    84790  37.011917 -113.598160             2       3.0        2.5
# 81832    84414  41.311148 -111.962272             1       3.0        1.0
# 26017    84770  37.126242 -113.610708             1       3.0        2.0
# 428      84790  37.049639 -113.554287             2       3.0        2.5
# ...        ...        ...         ...           ...       ...        ...
# 80060    84098  40.728772 -111.485843             2       3.0        1.5
# 34785    84770  37.115711 -113.606483             1       4.0        3.0
# 36467    84341  41.780189 -111.828759             1       4.0        3.0
# 6140     84664  40.097473 -111.590271             1       4.0        2.5
# 49214    84057  40.315266 -111.723188             0       2.0        1.0
#
#        squareFootage  lotSize  yearBuilt  daysOnMarket
# 2325          2300.0  13068.0     2023.0          92.0
# 32736         1611.0   1742.0     2023.0         397.0
# 81832         2018.0   9148.0     1960.0          29.0
# 26017         1624.0   1742.0     1988.0         374.0
# 428           1475.0    871.0     2015.0          14.0
# ...              ...      ...        ...           ...
# 80060         1694.0   1742.0     2021.0         698.0
# 34785         2119.0   2614.0     2023.0          33.0
# 36467         2684.0   8276.0     1996.0          82.0
# 6140          3669.0  10019.0     2024.0          99.0
# 49214          926.0    871.0     2023.0           7.0
#
# [10494 rows x 10 columns]

# %%
# Print the y_train model
print(y_train)
# Out:
# 2325     0.469000
# 32736    0.446890
# 81832    0.419500
# 26017    0.379900
# 428      0.310000
#            ...
# 80060    0.560996
# 34785    0.499900
# 36467    0.445000
# 6140     0.799900
# 49214    0.259000
# Name: price, Length: 10494, dtype: float64

# %%
# Print shapes for debugging
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)

# Create a StandardScaler model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# Transform the training and testing data using the X_scaler and y_scaler models
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Display the scaled data.
X_train_scaled
X_test_scaled

# Create a LinearRegression model and fit it to the scaled training data
model = LinearRegression()
model.fit(X_train_scaled, y_train)

# Make predictions using the X_test_scaled data
predictions = model.predict(X_test_scaled)

# Display the predictions.
predictions

# Display the actual prices.
y_test

# Display the model score.
model.score(X_test_scaled, y_test)

# Display the model coefficients.
model.coef_

# Display the model intercept.
model.intercept_

# Add a constant to the model (intercept)
X_train_scaled_const = sm.add_constant(X_train_scaled)
X_test_scaled_const = sm.add_constant(X_test_scaled)

# Fit the model using statsmodels
model_sm = sm.OLS(y_train, X_train_scaled_const).fit()

# Display the model summary
print(model_sm.summary())
# Out:
# X_train shape: (10494, 10)
# y_train shape: (10494,)
# X_test shape: (1853, 10)
# y_test shape: (1853,)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.369
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     613.6
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):               0.00
# Time:                        15:36:23   Log-Likelihood:                -10650.
# No. Observations:               10494   AIC:                         2.132e+04
# Df Residuals:                   10483   BIC:                         2.140e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6721      0.007    103.079      0.000       0.659       0.685
# x1            -0.1118      0.010    -11.302      0.000      -0.131      -0.092
# x2            -0.2164      0.013    -16.071      0.000      -0.243      -0.190
# x3             0.1763      0.012     15.236      0.000       0.154       0.199
# x4            -0.0218      0.007     -2.997      0.003      -0.036      -0.008
# x5            -0.1031      0.010    -10.582      0.000      -0.122      -0.084
# x6             0.1614      0.009     17.131      0.000       0.143       0.180
# x7             0.4409      0.010     42.901      0.000       0.421       0.461
# x8             0.0718      0.007     10.360      0.000       0.058       0.085
# x9            -0.1072      0.008    -13.355      0.000      -0.123      -0.091
# x10            0.0377      0.007      5.527      0.000       0.024       0.051
# ==============================================================================
# Omnibus:                    16357.594   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16076844.555
# Skew:                           9.690   Prob(JB):                         0.00
# Kurtosis:                     193.768   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Create the models.
model1 = LinearRegression()
model2 = xgb.XGBRegressor()
model3 = Lasso()
model4 = lgb.LGBMRegressor()

# Fit the first model to the full training data.
model1.fit(X_train, y_train)

# Fit the second model to the select training data.
model2.fit(X_train, y_train)

# Fit the third model to the select training data.
model3.fit(X_train, y_train)

# Fit the fourth model to the select training data.
model4.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Make predictions on the full training data.
y_pred1 = model1.predict(X_train)
y_pred2 = model2.predict(X_train)
y_pred3 = model3.predict(X_train)
y_pred4 = model4.predict(X_train)

# Make predictions on the select training data.
y_pred1_sel = model1.predict(X_train)
y_pred2_sel = model2.predict(X_train)
y_pred3_sel = model3.predict(X_train)
y_pred4_sel = model4.predict(X_train)

# Print the R2 scores for the full training data.
print("Linear Regression R2 Score (Full-Training):", r2_score(y_train, y_pred1))
print("XGBoost R2 Score (Full-Training):", r2_score(y_train, y_pred2))
print("Lasso R2 Score (Full-Training):", r2_score(y_train, y_pred3))
print("LGBM Regressor R2 Score (Full-Training):", r2_score(y_train, y_pred4))
print("-----------------------------------")


# Print the R2 scores for the select training data.
print("Linear Regression R2 Score (Select-Training):", r2_score(y_train, y_pred1_sel))
print("XGBoost R2 Score (Select-Training):", r2_score(y_train, y_pred2_sel))
print("Lasso R2 Score (Select-Training):", r2_score(y_train, y_pred3_sel))
print("LGBM Regressor R2 Score (Select-Training):", r2_score(y_train, y_pred4_sel))
print("-----------------------------------")

# Make predictions on the full testing data.
y_pred1_test = model1.predict(X_test)
y_pred2_test = model2.predict(X_test)
y_pred3_test = model3.predict(X_test)
y_pred4_test = model4.predict(X_test)
print("-----------------------------------")

# Print the R2 scores for the full testing data.
print("Linear Regression R2 Score (Full-Testing):", r2_score(y_test, y_pred1_test))
print("XGBoost R2 Score (Full-Testing):", r2_score(y_test, y_pred2_test))
print("Lasso R2 Score (Full-Testing):", r2_score(y_test, y_pred3_test))
print("LGBM Regressor R2 Score (Full-Testing):", r2_score(y_test, y_pred4_test))
print("-----------------------------------")

# Print the R2 scores for the select testing data.
print("Linear Regression R2 Score (Select-Testing):", r2_score(y_test, y_pred1_test))
print("XGBoost R2 Score (Select-Testing):", r2_score(y_test, y_pred2_test))
print("Lasso R2 Score (Select-Testing):", r2_score(y_test, y_pred3_test))
print("LGBM Regressor R2 Score (Select-Testing):", r2_score(y_test, y_pred4_test))
print("-----------------------------------")

# Display the model coefficients.
print("Linear Regression Coefficients:", model1.coef_)
print("Lasso Coefficients:", model3.coef_)
print("XGBoost Feature Importances:", model2.feature_importances_)
print("LGBM Regressor Feature Importances:", model4.feature_importances_)
print("Linear Regression Intercept:", model1.intercept_)
print("Lasso Intercept:", model3.intercept_)
print("XGBoost Intercept:", model2.intercept_)
print("Linear Regression Coefficients (Select):", model1.coef_)
print("Lasso Coefficients (Select):", model3.coef_)
print("XGBoost Feature Importances (Select):", model2.feature_importances_)
print("LGBM Regressor Feature Importances (Select):", model4.feature_importances_)
print("Linear Regression Intercept (Select):", model1.intercept_)
print("Lasso Intercept (Select):", model3.intercept_)

# Display the model scores.
print("Linear Regression Score:", model1.score(X_test, y_test))
print("XGBoost Score:", model2.score(X_test, y_test))
print("Lasso Score:", model3.score(X_test, y_test))
print("LGBM Regressor Score:", model4.score(X_test, y_test))

# # Display the model scores for the select data.
# print("Linear Regression Score (Select):", model1.score(X_sel, y_test))
# print("XGBoost Score (Select):", model2.score(X_sel, y_test))
# print("Lasso Score (Select):", model3.score(X_sel, y_test))
# print("LGBM Regressor Score (Select):", model4.score(X_sel, y_test))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000454 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1420
# [LightGBM] [Info] Number of data points in the train set: 10494, number of used features: 10
# [LightGBM] [Info] Start training from score 0.672119
# Linear Regression R2 Score (Full-Training): 0.3692308088110886
# XGBoost R2 Score (Full-Training): 0.9937717704074542
# Lasso R2 Score (Full-Training): 0.3221940725594993
# LGBM Regressor R2 Score (Full-Training): 0.9303394362487681
# -----------------------------------
# Linear Regression R2 Score (Select-Training): 0.3692308088110886
# XGBoost R2 Score (Select-Training): 0.9937717704074542
# Lasso R2 Score (Select-Training): 0.3221940725594993
# LGBM Regressor R2 Score (Select-Training): 0.9303394362487681
# -----------------------------------
# -----------------------------------
# Linear Regression R2 Score (Full-Testing): 0.389265658281994
# XGBoost R2 Score (Full-Testing): 0.8968560182059098
# Lasso R2 Score (Full-Testing): 0.3249477765317168
# LGBM Regressor R2 Score (Full-Testing): 0.8666451105569705
# -----------------------------------
# Linear Regression R2 Score (Select-Testing): 0.389265658281994
# XGBoost R2 Score (Select-Testing): 0.8968560182059098
# Lasso R2 Score (Select-Testing): 0.3249477765317168
# LGBM Regressor R2 Score (Select-Testing): 0.8666451105569705
# -----------------------------------
# Linear Regression Coefficients: [-3.83880334e-04 -1.59782305e-01  2.60036935e-01 -3.04588785e-02
#  -9.69456350e-02  1.85969874e-01  3.49091139e-04  2.92535291e-06
#  -5.70613203e-03  3.65598719e-04]
# Lasso Coefficients: [-2.09235552e-04 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  3.32465455e-04  3.83406524e-06
#  -0.00000000e+00  3.28835327e-04]
# XGBoost Feature Importances: [0.03810056 0.06962344 0.24109149 0.08418801 0.01111102 0.04469034
#  0.39985898 0.03527516 0.06177582 0.0142851 ]
# LGBM Regressor Feature Importances: [234 444 527  22  93 201 637 347 286 209]
# Linear Regression Intercept: 79.10208643041469
# Lasso Intercept: 17.477686354906332
# XGBoost Intercept: [0.67211854]
# Linear Regression Coefficients (Select): [-3.83880334e-04 -1.59782305e-01  2.60036935e-01 -3.04588785e-02
#  -9.69456350e-02  1.85969874e-01  3.49091139e-04  2.92535291e-06
#  -5.70613203e-03  3.65598719e-04]
# Lasso Coefficients (Select): [-2.09235552e-04 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  3.32465455e-04  3.83406524e-06
#  -0.00000000e+00  3.28835327e-04]
# XGBoost Feature Importances (Select): [0.03810056 0.06962344 0.24109149 0.08418801 0.01111102 0.04469034
#  0.39985898 0.03527516 0.06177582 0.0142851 ]
# LGBM Regressor Feature Importances (Select): [234 444 527  22  93 201 637 347 286 209]
# Linear Regression Intercept (Select): 79.10208643041469
# Lasso Intercept (Select): 17.477686354906332
# Linear Regression Score: 0.389265658281994
# XGBoost Score: 0.8968560182059098
# Lasso Score: 0.3249477765317168
# LGBM Regressor Score: 0.8666451105569705
# c:\Users\kerim\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## Evaluate the model

# %%
# Calculate the mean_squared_error and the r-squared value for the testing data for models 1 through model 4.
mse1 = mean_squared_error(y_test, model1.predict(X_test))
r21 = r2_score(y_test, model1.predict(X_test))
mse2 = mean_squared_error(y_test, model2.predict(X_test))
r22 = r2_score(y_test, model2.predict(X_test))
mse3 = mean_squared_error(y_test, model3.predict(X_test))
r23 = r2_score(y_test, model3.predict(X_test))
mse4 = mean_squared_error(y_test, model4.predict(X_test))
r24 = r2_score(y_test, model4.predict(X_test))

# Fit the fourth model to the training data.
model4.fit(X_train, y_train)

mse4 = mean_squared_error(y_test, model4.predict(X_test))
r24 = r2_score(y_test, model4.predict(X_test))

# Use our models to make predictions.
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)
y_pred3 = model3.predict(X_test)
y_pred4 = model4.predict(X_test)

# Score the predictions with mse and r2.
scoremodel1 = model1.score(X_test, y_test) 
scoremodel2 = model2.score(X_test, y_test)
scoremodel3 = model3.score(X_test, y_test)
scoremodel4 = model4.score(X_test, y_test)

# Print the mean squared error and r-squared value for the testing data for models 1 through model 7.
print(f"All Features:")
print(f"mean squared error (MSE): {mse1}")
print(f"R-squared (R2): {r21}")
print("---------------------")
print(f"Select Features:")
print(f"mean squared error (MSE): {mse2}")
print(f"R-squared (R2): {r22}")
print("---------------------")
print(f"Select Features:")
print(f"mean squared error (MSE): {mse3}")
print(f"R-squared (R2): {r23}")
print("---------------------")
print(f"Select Features:")
print(f"mean squared error (MSE): {mse4}")
print(f"R-squared (R2): {r24}")

# Print the model scores.
print(f"Linear Regression Model Score: {scoremodel1}")
print(f"XGBRegressor Model Score: {scoremodel2}")
print(f"Lasso Model Score: {scoremodel3}")
print(f"RandomForestClassifier Model Score: {scoremodel4}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1420
# [LightGBM] [Info] Number of data points in the train set: 10494, number of used features: 10
# [LightGBM] [Info] Start training from score 0.672119
# All Features:
# mean squared error (MSE): 0.4024492093252928
# R-squared (R2): 0.389265658281994
# ---------------------
# Select Features:
# mean squared error (MSE): 0.06796770884526497
# R-squared (R2): 0.8968560182059098
# ---------------------
# Select Features:
# mean squared error (MSE): 0.4448320898803026
# R-squared (R2): 0.3249477765317168
# ---------------------
# Select Features:
# mean squared error (MSE): 0.08787547408098667
# R-squared (R2): 0.8666451105569705
# Linear Regression Model Score: 0.389265658281994
# XGBRegressor Model Score: 0.8968560182059098
# Lasso Model Score: 0.3249477765317168
# RandomForestClassifier Model Score: 0.8666451105569705

# %%
# Explain the models with SHAP
explainer = shap.Explainer(model1, X_train)
shap_values = explainer(X_train)

# Install shap package
# %pip install shap

import shap

# Create the explainer object
explainer = shap.Explainer(model1, X_train)

# Get the SHAP values for the first observation
shap_values = explainer(X_train.iloc[0:1])

# Visualize the SHAP values
shap.plots.force(shap_values)
# Out:
# Requirement already satisfied: shap in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (0.46.0)
# Requirement already satisfied: numpy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (1.4.2)
# Requirement already satisfied: pandas in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (4.66.4)
# Requirement already satisfied: packaging>20.9 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (23.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (0.59.1)
# Requirement already satisfied: cloudpickle in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shap) (2.2.1)
# Requirement already satisfied: colorama in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from numba->shap) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# <div id='iJ4BZB8BPOAG2VLCO4COK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7135250811852387, "outValue": 0.4179776617891666, "link": "identity", "featureNames": ["zipCode", "latitude", "longitude", "propertyType", "bedrooms", "bathrooms", "squareFootage", "lotSize", "yearBuilt", "daysOnMarket"], "features": {"0": {"effect": -0.17278453855141787, "value": 84720.0}, "1": {"effect": 0.40060570835635206, "value": 37.680984}, "2": {"effect": -0.2875473603961469, "value": -113.145535}, "3": {"effect": 0.005787186911678269, "value": 1.0}, "4": {"effect": -0.16480757955315858, "value": 5.0}, "5": {"effect": 0.034404426718402624, "value": 2.5}, "6": {"effect": -0.04693530367303236, "value": 2300.0}, "7": {"effect": 0.021751637112326003, "value": 13068.0}, "8": {"effect": -0.0908986832291318, "value": 2023.0}, "9": {"effect": 0.004877086908056446, "value": 92.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJ4BZB8BPOAG2VLCO4COK')
#   );
# </script>

# %%
# Create Shapley values for the XGBRegressor model.
explainer2 = shap.Explainer(model2, X_train)
shap_values2 = explainer2(X_train.iloc[0:1])
shap.plots.force(shap_values2)
# Out:
# <div id='iQZD5OMA8VP3XSPO3HWW8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.8185939007221024, "outValue": 0.4817990531449179, "link": "identity", "featureNames": ["zipCode", "latitude", "longitude", "propertyType", "bedrooms", "bathrooms", "squareFootage", "lotSize", "yearBuilt", "daysOnMarket"], "features": {"0": {"effect": 0.27110754944791554, "value": 84720.0}, "1": {"effect": -0.45215247559506677, "value": 37.680984}, "2": {"effect": -0.19334376239297854, "value": -113.145535}, "3": {"effect": 0.010906712653231808, "value": 1.0}, "4": {"effect": 0.012577524828375318, "value": 5.0}, "5": {"effect": -0.013489016256498872, "value": 2.5}, "6": {"effect": -0.06942673469035071, "value": 2300.0}, "7": {"effect": 0.05434890478973102, "value": 13068.0}, "8": {"effect": 0.0483472945336689, "value": 2023.0}, "9": {"effect": -0.005670844895212213, "value": 92.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iQZD5OMA8VP3XSPO3HWW8')
#   );
# </script>

# %%
import shap

# Initialize the SHAP TreeExplainer
explainer = shap.TreeExplainer(model2)

# %%
# Compute SHAP values for the test set
shap_values = explainer.shap_values(X_test)

# %%
# Compute SHAP interaction values
shap_interaction_values = explainer.shap_interaction_values(X_test)

# %%
shap.summary_plot(shap_interaction_values, X_test)

# %%
# Example: Interaction between 'bathrooms' and 'bedrooms'
shap.dependence_plot(('bathrooms', 'bedrooms'), shap_interaction_values, X_test)

# %%
# Install shapiq package
# %pip install shapiq

from shapiq import Explainer

__all__ = ["Explainer", "TreeExplainer"]
# Out:
# Requirement already satisfied: shapiq in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.13.1)
# Requirement already satisfied: pandas in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.4.2)
# Requirement already satisfied: tqdm in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (4.66.4)
# Requirement already satisfied: requests in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.32.2)
# Requirement already satisfied: matplotlib in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.8.4)
# Requirement already satisfied: colour in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (0.1.5)
# Requirement already satisfied: networkx in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (2.2.0)
# Requirement already satisfied: colorama in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from tqdm->shapiq) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib->shapiq) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Get interaction value for specific feature pairs
feature_1 = 'bathrooms'
feature_2 = 'bedrooms'
interaction_matrix = shap_interaction_values  # For regression models
interaction_value = interaction_matrix[:, X_test.columns.get_loc(feature_1), X_test.columns.get_loc(feature_2)].mean()
print(f"Interaction value between {feature_1} and {feature_2}: {interaction_value}")
# Out:
# Interaction value between bathrooms and bedrooms: -0.0011318606557324529

# %%
# Create Shapley interaction values for the XGBRegressor model.
# %pip install shapiq

from shapiq import Explainer

explainer = Explainer(model=model2, data=X_train.values, max_order=2)

# explainer = shap.Explainer(model2, X_train, max_order=2)
shap_interaction_values = explainer.explain(X_train.iloc[0])
# Out:
# Requirement already satisfied: shapiq in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.13.1)
# Requirement already satisfied: pandas in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.4.2)
# Requirement already satisfied: tqdm in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (4.66.4)
# Requirement already satisfied: requests in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.32.2)
# Requirement already satisfied: matplotlib in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.8.4)
# Requirement already satisfied: colour in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (0.1.5)
# Requirement already satisfied: networkx in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (2.2.0)
# Requirement already satisfied: colorama in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from tqdm->shapiq) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib->shapiq) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\kerim\anaconda3\envs\dev\lib\site-packages\shapiq\explainer\utils.py:119: UserWarning: No class_index provided. Explaining the 2nd '1' class for classification models. Please provide the class_index to explain a different class. Disregard this warning for regression models.
#   warnings.warn(WARNING_NO_CLASS_INDEX)
# c:\Users\kerim\anaconda3\envs\dev\lib\site-packages\shapiq\explainer\tree\treeshapiq.py:141: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_relevant = x[self._relevant_features]
# c:\Users\kerim\anaconda3\envs\dev\lib\site-packages\shapiq\explainer\tree\treeshapiq.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[child_edge_feature] <= feature_threshold:

# %%
# Create Shapley interaction values for the XGBRegressor model.
# %pip install shapiq

from shapiq import Explainer

explainer = shap.Explainer(model2, X_train, max_order=2)
shap_interaction_values = explainer.shap_interaction_values(X_train)
shap_interaction_values = explainer.explain(X[0], budget=0.95)
# Out:
# Requirement already satisfied: shapiq in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.13.1)
# Requirement already satisfied: pandas in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.4.2)
# Requirement already satisfied: tqdm in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (4.66.4)
# Requirement already satisfied: requests in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.32.2)
# Requirement already satisfied: matplotlib in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.8.4)
# Requirement already satisfied: colour in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (0.1.5)
# Requirement already satisfied: networkx in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (2.2.0)
# Requirement already satisfied: colorama in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from tqdm->shapiq) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib->shapiq) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[419], line 6
#       2 get_ipython().run_line_magic('pip', 'install shapiq')
#       4 from shapiq import Explainer
# ----> 6 explainer = shap.Explainer(model2, X_train, max_order=2)
#       7 shap_interaction_values = explainer.shap_interaction_values(X_train)
#       8 shap_interaction_values = explainer.explain(X[0], budget=0.95)
#
# File c:\Users\kerim\anaconda3\envs\dev\lib\site-packages\shap\explainers\_explainer.py:188, in Explainer.__init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     186 elif algorithm == "tree":
#     187     self.__class__ = explainers.TreeExplainer
# --> 188     explainers.TreeExplainer.__init__(self, self.model, self.masker, link=self.link, feature_names=self.feature_names, linearize_link=linearize_link, **kwargs)
#     189 elif algorithm == "additive":
#     190     self.__class__ = explainers.AdditiveExplainer
#
# TypeError: TreeExplainer.__init__() got an unexpected keyword argument 'max_order'

# %%
# Create Shapley interaction values for the XGBRegressor model.
# %pip install shapiq

from shapiq import Explainer

explainer = shap.Explainer(model = model2, X = X_train, max_order=2)
shap_interaction_values = explainer.shap_interaction_values(X_train)
shap_interaction_values = explainer.explain(X[0], budget=0.95)
# Out:
# Requirement already satisfied: shapiq in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.26.4)
# Requirement already satisfied: scipy in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.13.1)
# Requirement already satisfied: pandas in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (1.4.2)
# Requirement already satisfied: tqdm in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (4.66.4)
# Requirement already satisfied: requests in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (2.32.2)
# Requirement already satisfied: matplotlib in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.8.4)
# Requirement already satisfied: colour in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (0.1.5)
# Requirement already satisfied: networkx in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from shapiq) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from matplotlib->shapiq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from pandas->shapiq) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from requests->shapiq) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from scikit-learn->shapiq) (2.2.0)
# Requirement already satisfied: colorama in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from tqdm->shapiq) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kerim\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib->shapiq) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 6
#       2 get_ipython().run_line_magic('pip', 'install shapiq')
#       4 from shapiq import Explainer
# ----> 6 explainer = shap.Explainer(model = model2, X = X_train, max_order=2)
#       7 shap_interaction_values = explainer.shap_interaction_values(X_train)
#       8 shap_interaction_values = explainer.explain(X[0], budget=0.95)
#
# File c:\Users\kerim\anaconda3\envs\dev\lib\site-packages\shap\explainers\_explainer.py:188, in Explainer.__init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     186 elif algorithm == "tree":
#     187     self.__class__ = explainers.TreeExplainer
# --> 188     explainers.TreeExplainer.__init__(self, self.model, self.masker, link=self.link, feature_names=self.feature_names, linearize_link=linearize_link, **kwargs)
#     189 elif algorithm == "additive":
#     190     self.__class__ = explainers.AdditiveExplainer
#
# TypeError: TreeExplainer.__init__() got an unexpected keyword argument 'X'

# %%
# Create Shapley values for the linear regression model.
explainer = shap.Explainer(model1, X_train)
shap_values1 = explainer(X_train.iloc[0:1])
shap.plots.force(shap_values1)
# Out:
# <div id='iLHAD87IDYPLBMAN0MC3U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7321885523754408, "outValue": 0.34554859362324253, "link": "identity", "featureNames": ["county", "propertyType", "bedrooms", "bathrooms", "squareFootage", "lotSize", "yearBuilt"], "features": {"0": {"effect": 0.036232676404242735, "value": 48.0}, "1": {"effect": 0.003800823763836188, "value": 1.0}, "2": {"effect": 0.27359373003895576, "value": 2.0}, "3": {"effect": -0.15322403902378523, "value": 1.0}, "4": {"effect": -0.6772471854188659, "value": 923.0}, "5": {"effect": -0.005868431536199869, "value": 6534.0}, "6": {"effect": 0.1360724670196181, "value": 1895.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iLHAD87IDYPLBMAN0MC3U')
#   );
# </script>

# %%
# Calculate SHAP values for all observations in X_train
shap_values = explainer(X_train)

# Create a SHAP summary plot
shap.summary_plot(shap_values, X_train)

# %%
# Calculate SHAP values for all observations in X_test
shap_values = explainer(X_test)

# Create a SHAP summary plot
shap.summary_plot(shap_values, X_test)

# %%
# Print the column names of X_test to verify the correct feature names
print("Columns in X_test:", X_test.columns)

# Create a SHAP dependence plot to show the effect of a single feature across the whole dataset.
shap.dependence_plot('squareFootage', shap_values, X_test, interaction_index=None)
shap.dependence_plot('latitude', shap_values, X_test, interaction_index=None)
shap.dependence_plot('longitude', shap_values, X_test, interaction_index=None)
shap.dependence_plot('lotSize', shap_values, X_test, interaction_index=None)
shap.dependence_plot('bathrooms', shap_values, X_test, interaction_index=None)
shap.dependence_plot('bedrooms', shap_values, X_test, interaction_index=None)
shap.dependence_plot('yearBuilt', shap_values, X_test, interaction_index=None)
shap.dependence_plot('daysOnMarket', shap_values, X_test, interaction_index=None)
shap.dependence_plot('propertyType', shap_values, X_test, interaction_index=None)
# Out:
# Columns in X_test: Index(['zipCode', 'latitude', 'longitude', 'propertyType', 'bedrooms',
#        'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt', 'daysOnMarket'],
#       dtype='object')

# %%
# Provide code to create the adjusted r-squared function
def r2_adj(x, y, model):
    r2 = model.score(x,y)
    n_cols = x.shape[1]
    return 1 - (1 - r2) * (len(y) - 1) / (len(y) - n_cols - 1)

# %%
# Calculate the adjusted r-squared value of the model.
adj_r2_model1 = r2_adj(X_test, y_test, model1)
adj_r2_model2 = r2_adj(X_test, y_test, model2)

# %%
# Print the adjusted r-squared value of the model.
print(f"Linear Regression Model Adjusted R-squared: {adj_r2_model1}")
print(f"XGBRegressor Model Adjusted R-squared: {adj_r2_model2}")
# Out:
# Linear Regression Model Adjusted R-squared: 0.3567493528251785
# XGBRegressor Model Adjusted R-squared: 0.7806559238171243

# %%
# Create a visual representation. 
import matplotlib.pyplot as plt

# Data for visualization
features = ['squareFootage', 'latitude', 'longitude', 'bathrooms', 'yearBuilt', 'daysOnMarket', 'bedrooms']
importance = [abs(coef) for coef in model1.coef_]  # Use coefficients from model1 (Linear Regression model)

# Plotting
plt.figure(figsize=(10, 6))
plt.barh(features, importance, align='center')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importance for Price Prediction')
plt.gca().invert_yaxis()  # Invert y-axis for descending order
plt.tight_layout()
plt.show()

# %%
# Examine linear regression on the better training data using cross validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import pandas as pd

# Encode categorical variables
X_train_encoded = pd.get_dummies(X_train)
X_test_encoded = pd.get_dummies(X_test)

# Align the train and test dataframes by the columns
X_train_encoded, X_test_encoded = X_train_encoded.align(X_test_encoded, join='left', axis=1)

# Convert datetime strings in y_train and y_test to numerical values (e.g., timestamps)
y_train = pd.to_datetime(y_train).astype('int64') / 10**9  # Convert to seconds since epoch
y_test = pd.to_datetime(y_test).astype('int64') / 10**9  # Convert to seconds since epoch

# Create a KFold object
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Perform cross-validation on the linear regression model
cross_val_scores = cross_val_score(model1, X_train_encoded, y_train, scoring='r2', cv=kf)

# Print the cross-validation scores
print("Cross Validation Scores:", cross_val_scores)

# Calculate the mean of the cross-validation scores
cross_val_mean = cross_val_scores.mean()

# Print the mean of the cross-validation scores
print("Mean Cross Validation Score:", cross_val_mean)

# Examine XGBRegressor on the better training data using cross validation
# Perform cross-validation on the XGBRegressor model
cross_val_scores2 = cross_val_score(model2, X_train_encoded, y_train, scoring='r2', cv=kf)

# Print the cross-validation scores
print("Cross Validation Scores:", cross_val_scores2)

# Calculate the mean of the cross-validation scores
cross_val_mean2 = cross_val_scores2.mean()

# Print the mean of the cross-validation scores
print("Mean Cross Validation Score:", cross_val_mean2)

# Print the adjusted r-squared value of the model.
print(f"Adjusted R-squared value for Linear Regression Model: {adj_r2_model1}")
print(f"Adjusted R-squared value for XGBRegressor Model: {adj_r2_model2}")

# Save the model to disk
import joblib
joblib.dump(model1, 'model1.joblib')
joblib.dump(model2, 'model2.joblib')
joblib.dump(X_train_encoded, 'X_train.joblib')
joblib.dump(y_train, 'y_train.joblib')
joblib.dump(X_test_encoded, 'X_test.joblib')
joblib.dump(y_test, 'y_test.joblib')
joblib.dump(cross_val_mean, 'cross_val_mean.joblib')
joblib.dump(cross_val_mean2, 'cross_val_mean2.joblib')
joblib.dump(adj_r2_model1, 'adj_r2_model1.joblib')
joblib.dump(adj_r2_model2, 'adj_r2_model2.joblib')

# Load the model from disk
loaded_model1 = joblib.load('model1.joblib')
loaded_model2 = joblib.load('model2.joblib')
loaded_X_train = joblib.load('X_train.joblib')
loaded_y_train = joblib.load('y_train.joblib')
loaded_X_test = joblib.load('X_test.joblib')
loaded_y_test = joblib.load('y_test.joblib')
loaded_cross_val_mean = joblib.load('cross_val_mean.joblib')
loaded_cross_val_mean2 = joblib.load('cross_val_mean2.joblib')
loaded_adj_r2_model1 = joblib.load('adj_r2_model1.joblib')
loaded_adj_r2_model2 = joblib.load('adj_r2_model2.joblib')

# Print the loaded model
print(loaded_model1)
print(loaded_model2)
print(loaded_X_train)
print(loaded_y_train)
print(loaded_X_test)
print(loaded_y_test)
print(loaded_cross_val_mean)
print(loaded_cross_val_mean2)
print(loaded_adj_r2_model1)
print(loaded_adj_r2_model2)

# Print the loaded model score
print(loaded_model1.score(loaded_X_test, loaded_y_test))
print(loaded_model2.score(loaded_X_test, loaded_y_test))
print(loaded_cross_val_mean)
print(loaded_cross_val_mean2)
print(loaded_adj_r2_model1)
print(loaded_adj_r2_model2)

# Print the loaded model predictions
print(loaded_model1.predict(loaded_X_test))
print(loaded_model2.predict(loaded_X_test))
# Out:
# Cross Validation Scores: [0.31799311 0.30714909 0.31102782 0.31465122 0.26130385]
# Mean Cross Validation Score: 0.30242501644490216
# Cross Validation Scores: [-6.18332913e-05 -1.48341337e-04 -5.96352983e-05 -2.51262606e-07
#  -3.18792793e-07]
# Mean Cross Validation Score: -5.407599640232519e-05
# Adjusted R-squared value for Linear Regression Model: 0.3567493528251785
# Adjusted R-squared value for XGBRegressor Model: 0.7806559238171243
# LinearRegression()
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
#        county  propertyType  bedrooms  bathrooms  squareFootage  lotSize  \
# 18737      48             1         2        1.0            923     6534
# 9048       48             1         3        2.0           1642     7841
# 6334       34             1         4        1.0           1523     5227
# 47085      25             1         4        3.5           2930     3049
# 31621       6             1         3        1.0           2239     6970
# ...       ...           ...       ...        ...            ...      ...
# 54343      49             0         3        2.0           1737      436
# 38158      21             1         3        2.0           1586    26136
# 860        52             2         3        2.0           1110     2614
# 15795      48             1         5        3.5           4036    13504
# 56422      57             1         5        3.0           2325     8712
#
#        yearBuilt
# 18737       1895
# 9048        1945
# 6334        1986
# 47085       2006
# 31621       1976
# ...          ...
# 54343       1999
# 38158       2018
# 860         1997
# 15795       2000
# 56422       1974
#
# [38423 rows x 7 columns]
# 18737    0.0
# 9048     0.0
# 6334     0.0
# 47085    0.0
# 31621    0.0
#         ...
# 54343    0.0
# 38158    0.0
# 860      0.0
# 15795    0.0
# 56422    0.0
# Name: price, Length: 38423, dtype: float64
#        county  propertyType  bedrooms  bathrooms  squareFootage  lotSize  \
# 29618      34             1         4        2.0           2050     4792
# 21722      34             1         4        2.5           1647     9148
# 32318      42             2         2        2.0           1371        0
# 43607      49             1         3        2.5           1506     8712
# 26364      52             1         3        2.0           1126     2178
# ...       ...           ...       ...        ...            ...      ...
# 54425      43             0         0        1.0            383        0
# 2720        2             1         5        3.0           3154    20038
# 21558      20             2         3        2.0           1310      871
# 45709      35             1         3        1.0            960     7841
# 33483      34             2         4        2.5           2243      436
#
#        yearBuilt
# 29618       1951
# 21722       1962
# 32318       2015
# 43607       1998
# 26364       1988
# ...          ...
# 54425       2023
# 2720        2020
# 21558       2023
# 45709       1955
# 33483       2022
#
# [18082 rows x 7 columns]
# 29618    0.0
# 21722    0.0
# 32318    0.0
# 43607    0.0
# 26364    0.0
#         ...
# 54425    0.0
# 2720     0.0
# 21558    0.0
# 45709    0.0
# 33483    0.0
# Name: price, Length: 18082, dtype: float64
# 0.30242501644490216
# -5.407599640232519e-05
# 0.3567493528251785
# 0.7806559238171243
# -1.0889048127198518e+18
# -1.5142193204532157e+18
# 0.30242501644490216
# -5.407599640232519e-05
# 0.3567493528251785
# 0.7806559238171243
# [0.47784661 0.36265719 0.37376952 ... 0.11957353 0.09214779 0.44117951]
# [0.57793635 0.51193404 1.319953   ... 0.28944373 0.37775853 0.52516633]
