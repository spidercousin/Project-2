# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

file = pd.read_csv('Cleaned.csv')
df = pd.DataFrame(file)

# %%
df.head()
# Out:
#    county  propertyType  bedrooms  bathrooms  squareFootage  lotSize  \
# 0      10             1         2        1.0            862     4792
# 1      56             1         3        1.0           1750     4792
# 2      20             1         5        4.0           3000    21780
# 3      48             1         3        2.5           4448    11326
# 4      48             1         3        2.0           1050     4792
#
#    yearBuilt   price
# 0       1941  360000
# 1       1941  314999
# 2       2021  540000
# 3       2024  777400
# 4       1998  379900

# %%
X_full = df.drop(columns = ['price'])
X_full.columns
# Out:
# Index(['county', 'propertyType', 'bedrooms', 'bathrooms', 'squareFootage',
#        'lotSize', 'yearBuilt'],
#       dtype='object')

# %%
y = df['price']

# %%
select_features = [ 'county', 'propertyType', 'bedrooms',  'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt']

# %%
X = df[select_features]
X
# Out:
#        county  propertyType  bedrooms  bathrooms  squareFootage  lotSize  \
# 0          10             1         2        1.0            862     4792
# 1          56             1         3        1.0           1750     4792
# 2          20             1         5        4.0           3000    21780
# 3          48             1         3        2.5           4448    11326
# 4          48             1         3        2.0           1050     4792
# ...       ...           ...       ...        ...            ...      ...
# 56500       5             1         4        3.0           2646    25265
# 56501      47             1         3        2.0           2028    19166
# 56502      47             1         4        2.0           1620    10454
# 56503      13             1         7        3.0           3194    16988
# 56504      21             0         2        2.0           1037     2178
#
#        yearBuilt
# 0           1941
# 1           1941
# 2           2021
# 3           2024
# 4           1998
# ...          ...
# 56500       2020
# 56501       2008
# 56502       2008
# 56503       2010
# 56504       1985
#
# [56505 rows x 7 columns]

# %%
y = df['price']
y
# Out:
# 0        360000
# 1        314999
# 2        540000
# 3        777400
# 4        379900
#           ...
# 56500    650000
# 56501    349000
# 56502    240000
# 56503    539999
# 56504    255000
# Name: price, Length: 56505, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (42378, 7) (14127, 7) (42378,) (14127,)

# %%
model1 = LinearRegression()
model2 = xgb.XGBRegressor()

# %%
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
mse1 = mean_squared_error(y_test, model1.predict(X_test))
r21 = r2_score(y_test, model1.predict(X_test))

mse2 = mean_squared_error(y_test, model2.predict(X_test))
r22 = r2_score(y_test, model2.predict(X_test))

# %%
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)

# %%
scoremodel1 = model1.score(X_test, y_test) 
scoremodel2 = model2.score(X_test, y_test)

# %%
print(f"Linear Regression Model Score: {scoremodel1}")
print(f"XGBRegressor Model Score: {scoremodel2}")
print(f"All Features:")
print(f"mean squared error (MSE): {mse1}")
print(f"R-squared (R2): {r21}")
print("---------------------")
print(f"Select Features:")
print(f"mean squared error (MSE): {mse2}")
print(f"R-squared (R2): {r22}")
# Out:
# Linear Regression Model Score: 0.3524571294254142
# XGBRegressor Model Score: 0.7702409029006958
# All Features:
# mean squared error (MSE): 446429588724.9149
# R-squared (R2): 0.3524571294254142
# ---------------------
# Select Features:
# mean squared error (MSE): 158400734154.51245
# R-squared (R2): 0.7702409029006958

# %%
#XGBRegressor seemed to have the best score by a long shot (~0.77)
#linear Regression had a way lower score (~0.35)
